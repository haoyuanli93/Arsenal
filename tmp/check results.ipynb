# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py as h5

# %% [markdown]
# # Load data

# %%
with h5.File('../output/statistics_hits_amox26916_85_2018_09_11_23_01_54.h5', 'r') as h5file:
    print("The entries are ")
    print(list(h5file.keys()))
    
    data = np.array(h5file['max_2d'])
# Out:
# The entries are
# ['max_2d', 'max_stack', 'mean_2d', 'mean_stack', 'min_2d', 'min_stack', 'pattern_num', 'square_sum_2d', 'square_sum_stack', 'std_2d', 'std_stack', 'sum_2d', 'sum_stack']

# %%
fig = plt.figure(figsize=(20,15))

plt.imshow(data, cmap='jet')
plt.colorbar()
plt.show()

# %%
np.save('../output/max_stack.npy', data)

# %%
with h5.File('../output/statistics_hits_amox26916_85_2018_09_10_22_06_15.h5', 'r') as h5file:
    print("The entries are ")
    print(list(h5file.keys()))
    
    data = np.array(h5file['max_2d'])
# Out:
# The entries are
# ['max_2d', 'max_stack', 'mean_2d', 'mean_stack', 'min_2d', 'min_stack', 'pattern_num', 'square_sum_2d', 'square_sum_stack', 'std_2d', 'std_stack', 'sum_2d', 'sum_stack']

# %%
fig = plt.figure(figsize=(20,15))

plt.imshow(data, cmap='jet')
plt.colorbar()
plt.show()
