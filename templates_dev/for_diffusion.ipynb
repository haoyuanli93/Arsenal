# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt

# %%
with h5.File('../../experiment_data/amox26916_run_85_all_pattern_bin_size_4.h5','r') as h5file:

    with h5.File("../../experiment_data/amox26916_run_85_for_diffusion.h5",'w') as tmp:
                
        for key in list(h5file.keys()):
            tmp.create_dataset(key, data = np.array(h5file[key +'/pattern']))

# %%
with h5.File("../../experiment_data/amox26916_run_85_for_diffusion.h5",'r') as tmp:
    data = np.array(tmp[key])

# %%
plt.imshow(data[0])
plt.show()
